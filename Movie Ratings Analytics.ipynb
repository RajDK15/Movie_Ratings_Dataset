# %%
import pandas as pd
import numpy as np
import os

# %%
file_path = 'C:\\Users\\HP\\OneDrive\\Desktop\\Jupyter notebooks\\P4-Movie-Ratings.csv'

# %%
# Introduction to Category data type
movies = pd.read_csv(file_path)
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.head(10)
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
# 5                   2012     Action                         39
# 6             27 Dresses     Comedy                         40
# 7       30 Days of Night     Horror                         50
# 8     30 Minutes or Less     Comedy                         43
# 9                  50/50     Comedy                         93
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
       'Budget (million $)', 'Year of release']

# %%
movies.head(10)
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
# 5                   2012     Action                         39
# 6             27 Dresses     Comedy                         40
# 7       30 Days of Night     Horror                         50
# 8     30 Minutes or Less     Comedy                         43
# 9                  50/50     Comedy                         93
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# ...

# %%
movies.Film.astype('category')
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies['Genre'] = movies['Genre'].astype('category')
categories = movies['Genre'].cat.categories
categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.Genre.astype('category')
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Joint Plots
j = sns.jointplot(data = movies, x= 'Rotten Tomatoes Ratings %', y = 'Audience Ratings %',
                 kind = 'hex')

# %%
# Histogram
m_1 = sns.distplot(movies['Audience Ratings %'], bins = 15)

# %%
n_1 = plt.hist(movies['Audience Ratings %'], bins = 15)

# %%
n_2 = plt.hist(movies['Rotten Tomatoes Ratings %'], bins = 15)

# %%
# Stacked Histograms
plt.hist(movies['Budget (million $)'])
plt.show()

# %%
movies[movies['Genre'] == 'Drama']['Budget (million $)']
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: Budget (million $), Length: 101, dtype: int64

# %%
plt.hist(movies[movies['Genre'] == 'Drama']['Budget (million $)'])
plt.show()

# %%
for gen in movies['Genre'].cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list_1 = list()
for gen in movies['Genre'].cat.categories:
    list_1.append(movies[movies['Genre'] == gen]['Budget (million $)'])

# %%
h = plt.hist(list_1, bins = 30, stacked = True, rwidth = 1)

# %%
list_1 = list()
my_labels = list()
for gen in movies['Genre'].cat.categories:
    list_1.append(movies[movies['Genre'] == gen]['Budget (million $)'])
    my_labels.append(gen)
h = plt.hist(list_1, bins = 30, stacked = True, rwidth = 2, label = my_labels)
plt.legend()
plt.show()

# %%
# Kernel Density  Estimate Plot
vis_1 = sns.lmplot(data = movies, x = 'Rotten Tomatoes Ratings %', y = 'Audience Ratings %', fit_reg = False,
                  hue = 'Genre', aspect = 1, height = 10)

# %%
k_1 = sns.kdeplot(x = movies['Rotten Tomatoes Ratings %'], y = movies['Audience Ratings %'],
                 shade = True, shade_lowest = False, cmap = 'Blues')

# %%
# Working with subplots()
k_2 = sns.kdeplot(x = movies['Budget (million $)'], y = movies['Audience Ratings %'])

# %%
f, axes = plt.subplots(1, 2, figsize=(12, 6))
k_1 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Audience Ratings %'], ax=axes[0])
k_2 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Rotten Tomatoes Ratings %'], ax=axes[1])
k_1.set(xlim=(-20, 160))
# Out:
# [(-20.0, 160.0)]

# %%
# Voilin Plots & Box Plots
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
w = sns.boxplot(data=movies[movies['Genre'] == 'Action'], x='Audience Ratings %', y='Rotten Tomatoes Ratings %')

# %%
w = sns.violinplot(data=movies[movies['Genre'] == 'Drama'], x='Audience Ratings %', y='Rotten Tomatoes Ratings %')

# %%
# Creating a facet Grid
r_1 = sns.FacetGrid(movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
r_1.map(plt.scatter, 'Genre', 'Year of release')  
r_1.add_legend()

# %%
r_1 = sns.FacetGrid(movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
r_1 = r_1.map(plt.scatter, "Rotten Tomatoes Ratings %", "Audience Ratings %")

# %%
# can also make a hist chart
r_1 = sns.FacetGrid(movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
r_1 = r_1.map(plt.hist,'Budget (million $)')

# %%
## back to scatterplots:
r_1 = sns.FacetGrid(movies, row = 'Genre', col = 'Year of release', hue = 'Genre')
kws = dict(s= 50, linewidth = 0.5, edgecolor = 'black')
r_1 = r_1.map(plt.scatter, "Rotten Tomatoes Ratings %", "Audience Ratings %", **kws)

# %%
## Controlling Axes and adding Diagonals
r_1 = sns.FacetGrid(movies, row='Genre', col='Year of release', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
r_1 = r_1.map(sns.scatterplot, "Rotten Tomatoes Ratings %", "Audience Ratings %", **kws)
r_1.set(xlim=(0, 100), ylim=(0, 100))
for ax in r_1.axes.flat:
    ax.plot((0,100), (0,100), c= 'gray', ls = '--')
r_1.add_legend()    
plt.show()

# %%
## Building dashboards
sns.set_style("darkgrid")
f, axes = plt.subplots(2, 2, figsize=(15, 15))
k_1 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Audience Ratings %'], ax=axes[0,0])
k_2 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Rotten Tomatoes Ratings %'], ax=axes[0,1])
k_1.set(xlim=(-20, 160))
k_2.set(xlim=(-20, 160))
w = sns.violinplot(data=movies[movies['Genre'] == 'Drama'], x='Year of release', y='Rotten Tomatoes Ratings %', ax = axes[1,0])
k_4 = sns.kdeplot(x = movies['Rotten Tomatoes Ratings %'], y = movies['Audience Ratings %'],
                shade = True, shade_lowest = False, cmap = 'Reds', ax = axes[1,1])
# to add hist plot we have to use the below code because hist chart is not a seaborn plot and has a different approach
# axes[1,1].hist(movies['Rotten Tomatoes Ratings %'], bins = 15) 
plt.show()

# %%
## Styling dashboards
sns.set_style("white", {'axes.facecolor':'black'})
f, axes = plt.subplots(2, 2, figsize=(15, 15))

k_1 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Audience Ratings %'], ax=axes[0,0] \
                 ,shade = True, shade_lowest = True, cmap = 'inferno')
## for the outline of the plot
k_1 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Audience Ratings %'], ax=axes[0,0] \
                 ,cmap = 'Blues')

k_2 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Rotten Tomatoes Ratings %'], ax=axes[0,1],\
                  shade = True, shade_lowest = True, cmap = 'cool')
k_2 = sns.kdeplot(x=movies['Budget (million $)'], y=movies['Rotten Tomatoes Ratings %'], ax=axes[0,1],\
                  cmap = 'summer')

w = sns.violinplot(data=movies[movies['Genre'] == 'Drama'], x='Year of release', y='Rotten Tomatoes Ratings %', ax = axes[1,0],
                  palette = 'YlOrRd')

k_4 = sns.kdeplot(x = movies['Rotten Tomatoes Ratings %'], y = movies['Audience Ratings %'],
                shade = True, shade_lowest = False, cmap = 'Blues', ax = axes[1,1])
k_4 = sns.kdeplot(x = movies['Rotten Tomatoes Ratings %'], y = movies['Audience Ratings %'],
                cmap = 'gist_gray', ax = axes[1,1])

# to add hist plot we have to use the below code because hist chart is not a seaborn plot and has a different approach
# axes[1,1].hist(movies['Rotten Tomatoes Ratings %'], bins = 15) 
k_1.set(xlim=(-20, 160))
k_2.set(xlim=(-20, 160))
plt.show()

# %%
# 1. Advanced visualization using pandas, numpy, matplotlib and seaborn libraries.
# 2. Applying seaborn skills to create a dashboard in Python.
# 3. Data visualization using different kind of plots i.e kde, hist, violin, box, joint plots.
